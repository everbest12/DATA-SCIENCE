# %% [markdown]
# # LET'S LEARN PANDAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import statsmodels.api as sm

# %%
df= pd.read_csv('student_habits_performance.csv')

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
y = data['study_hours_per_day']
x1 = data['exam_score']

# %% [markdown]
# plt.scatter(x1,y)
# plt.xlabel('exam_score', fontsize = 20)
# plt.ylabel('study_hours_per_day', fontsize = 20)
# plt.show()

# %%
df['netflix_hours'].max()
# Out:
# 5.4

# %%
df['netflix_hours'].min()
# Out:
# 0.0

# %%
df['netflix_hours'].mean()
# Out:
# 1.8197

# %% [markdown]
# # DATAFRAME BASICS IN PANDAS
# ## Command	Description
# 1. df.head()	First 5 rows
# 2. df.tail()	Last 5 rows
# 3. df.shape	(rows, columns)
# 4. df.columns	List of column names
# 5. df.index	List of row labels
# 6. df.info()	Summary (data types, nulls)
# 7. df.describe()	Summary statistics (numerical)

# %% [markdown]
# ## CREARTING AND READING A DATAFRAME

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head
# Out:
# <bound method NDFrame.head of     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %% [markdown]
# PRINT LAST 5 ROWS

# %%
df.tail(5)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 995         Fair                   2              High School
# ...

# %% [markdown]
# PRINT FIRST 5 ROWS

# %%
df.head(5)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %% [markdown]
# ## INDEXING AND SLICING
# Lets print between row 5 to 19

# %%
df[5:20]
# Out:
#    student_id  age  gender  study_hours_per_day  social_media_hours  \
# 5       S1005   24    Male                  7.2                 1.3
# 6       S1006   21  Female                  5.6                 1.5
# 7       S1007   21  Female                  4.3                 1.0
# 8       S1008   23  Female                  4.4                 2.2
# 9       S1009   18  Female                  4.8                 3.1
# 10      S1010   19  Female                  4.6                 3.7
# 11      S1011   23    Male                  3.9                 2.4
# 12      S1012   19  Female                  3.7                 2.1
# 13      S1013   19  Female                  3.4                 2.7
# 14      S1014   24    Male                  2.4                 1.5
# 15      S1015   21    Male                  3.1                 5.0
# 16      S1016   20    Male                  1.0                 0.6
# 17      S1017   24  Female                  3.4                 2.7
# ...

# %% [markdown]
# ## LETS PRINT COLUMN

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %% [markdown]
# ## TO PRINT INDIVIDUAL COLUMNS

# %%
df.diet_quality.head(5)
# Out:
# 0    Fair
# 1    Good
# 2    Poor
# 3    Poor
# 4    Fair
# Name: diet_quality, dtype: object

# %%
df.extracurricular_participation.head(10)
# Out:
# 0    Yes
# 1     No
# 2     No
# 3    Yes
# 4     No
# 5     No
# 6     No
# 7     No
# 8     No
# 9    Yes
# Name: extracurricular_participation, dtype: object

# %%
type(df['parental_education_level'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df[['parental_education_level', 'diet_quality', 'exam_score']].head(10)
# Out:
#   parental_education_level diet_quality  exam_score
# 0                   Master         Fair        56.2
# 1              High School         Good       100.0
# 2              High School         Poor        34.3
# 3                   Master         Poor        26.8
# 4                   Master         Fair        66.4
# 5                   Master         Fair       100.0
# 6                   Master         Good        89.8
# 7                 Bachelor         Fair        72.6
# 8                 Bachelor         Good        78.9
# 9                 Bachelor         Good       100.0

# %%
df[['parental_education_level', 'diet_quality', 'exam_score']]
# Out:
# <bound method NDFrame.describe of     parental_education_level diet_quality  exam_score
# 0                     Master         Fair        56.2
# 1                High School         Good       100.0
# 2                High School         Poor        34.3
# 3                     Master         Poor        26.8
# 4                     Master         Fair        66.4
# ..                       ...          ...         ...
# 995              High School         Fair        76.1
# 996              High School         Poor        65.9
# 997                 Bachelor         Good        64.4
# 998                 Bachelor         Fair        69.7
# 999                 Bachelor         Good        74.9
#
# [1000 rows x 3 columns]>

# %% [markdown]
# # OPERATIONS WITH DATAFRAMES
